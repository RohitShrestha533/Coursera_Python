# %% [markdown]
# WEB SCRAPING

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get("https://www.hubanepal.com/").text

# %%
soup = BeautifulSoup(page,"html.parser")
txt=soup.get_text()
print(txt)
# Out:
# Home | HUBA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# top of pageMenu
#
#
#
#
#
#
#
# About UsWishlistLogin
#
#
#
#
#
# SPRING / SUMMERExplore NowFALL / WINTERExplore NowACCESSORIES Explore NowBAGSExplore NowTihar Special OfferGet Up To 25% OFF on your purchasesShop NowLATEST ARRIVALSTRENDINGQuick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View HUBA BASIC T-SHIRT V2Regular Price₨1,800.00Sale Price₨1,710.00Quick View ICE DENIMPrice₨2,850.00Quick View PIXELATED HOODIEPrice₨3,800.00Quick View PIXELATED HOODIEPrice₨3,800.00Quick View HUBA VISTA HALF PUFFERPre OrderQuick View HUBA VISTA HALF PUFFERPre OrderQuick View HUBA WAVE PUFFERPre OrderQuick View HUBA Summer Sweatshirt -BeigePrice₨2,300.00Quick View HUBA Summer Sweatshirt -BeigePrice₨2,300.00Quick View HUBA Summer Sweatshirt -BlueOut of stockQuick View HUBA Summer Sweatshirt -BlueOut of stockQuick View HUBA Summer Sweatshirt - GreenPrice₨2,300.00Quick View HUBA Summer Sweatshirt - GreenPrice₨2,300.00Quick View HUBA Summer Sweatshirt - BlackOut of stockQuick View HUBA Summer Sweatshirt - BlackOut of stockQuick View HUBA Fresco PantOut of stockQuick View HUBA Fresco PantOut of stockQuick View HUBA Untouchable T-shirt (White)Price₨1,900.00Quick View HUBA Untouchable T-shirt (White)Price₨1,900.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EXPLORE NOWHUBA IN FOCUSHUBA REKO JACKETUpgrade your wardrobe with HUBA Reco Jacket, combining style and comfort in one. This unisex jacket has a classic shirt collar, smooth zipper closure, and sleek welt pockets for a modern look. The special wrinkle fabric adds a stylish touch, and the subtle logo on the sleeve gives it a unique detail. Great for both casual wear and semi-formal occasions.SHOP NOWA STYLE FOR EVERY STORYSince 2021, HUBA has proudly focused on creating modern fashion that combines style, practicality, and affordability. Our designs aim to go beyond fashion trends, offering timeless pieces that balance structure and visual appeal. With a forward-thinking approach, we craft clothing that's both stylish and functional for everyday wear.MEN'S COLLECTIONWOMEN'S COLLECTIONMEN'S COLLECTIONWOMEN'S COLLECTIONA STYLE FOR EVERY STORYSince 2021, HUBA has been synonymous with cutting-edge style. Its intellectual universe combines concept, structure and image through codes that go beyond trends. HUBA is an attempt to design and provide clothes which are both functional as well as aesthetically pleasing in affordable price. Influential, innovative and progressive, HUBA is reinventing a wholly modern approach to fashion.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NEW ARRIVALEXPLORE NOWBhanimandal, LalitpurVISIT OUR STOREWorldwide deliveryWe provide Door to Door delivery in almost all part of World.Made In NepalAll our products are exclusively crafted in Nepal.Exchange & RefundEasy exchanges & refunds if your item arrives damage.You can now shop your favorite style directly on Instagram and Facebook. Just browse our page, choose the looks you love, and send us a direct message to place your order. We'll handle everything from there, making sure your clothes are delivered quickly and right to your door.Our ServicesSeamless Shopping & Fast DeliveryEXPLORE NOWSTAY IN TOUCHSUBSCRIBEOUR SERVICESPrivacy PolicyShipping PolicyTerms and ConditionsExchange and RefundSHOP NOWShopMen's CollectionLatest ArrivalsWomen's CollectionQUICK LINKSAbout HUBAContact UsGET CONNECTEDKathmandu, Nepal
#
#
#
#
#
# +977 9703723253
#
#
#
#
#
# customercare@hubanepal.com
#
#
#
#
#
# facebook
#
#
#
#
#
# instagram
#
#
#
#
#
# instagram
#
#
#
#
#
# COPYRIGHT © 2024 HUBA | All Rights Reserved
#
#
#
#
#
# NewBagsSummer / SpringFall / WinterWomenAccessoriesbottom of page

# %%
URL = "https://en.wikipedia.org/wiki/List_of_banks_in_Nepal"
tables = pd.read_html(URL)
df = tables[0]
print(df)
# Out:
#                        Bank Name                Headquarters Paid-up capital  \
# 0   Agriculture Development Bank      Ramshahpath, Kathmandu   रु 19.29 Arab
# 1                     Nepal Bank      Bhugol Park, Kathmandu   रु 14.69 Arab
# 2          Rastriya Banijya Bank     Singhadurbar, Kathmandu   रु 15.64 Arab
# 3    Citizens Bank International  Narayanhitipath, Kathmandu   रु 14.77 Arab
# 4                   Everest Bank         Lazimpat, Kathmandu   रु 12.94 Arab
# 5        Global IME Bank Limited         Kamaladi, Kathmandu   रु 38.12 Arab
# 6                 Himalayan Bank         Kamaladi, Kathmandu   रु 21.66 Arab
# 7                    Kumari Bank            Naxal, Kathmandu   रु 26.23 Arab
# 8             Laxmi Sunrise Bank         Hattisar, Kathmandu   रु 24.35 Arab
# 9             Machhapuchhre Bank         Lazimpat, Kathmandu   रु 11.62 Arab
# 10                    Nabil Bank        Teendhara, Kathmandu   रु 27.06 Arab
# 11    Nepal Investment Mega Bank       Durbarmarg, Kathmandu   रु 34.13 Arab
# 12                Nepal SBI Bank         Kamaladi, Kathmandu   रु 10.50 Arab
# 13                 NIC Asia Bank       Thapathali, Kathmandu   रु 14.92 Arab
# 14                NMB Bank Nepal       Babarmahal, Kathmandu   रु 18.37 Arab
# 15                   Prabhu Bank        Anamnagar, Kathmandu   रु 23.54 Arab
# 16         Prime Commercial Bank     Kamalpokhari, Kathmandu   रु 19.40 Arab
# 17                   Sanima Bank     Narayanchaur, Kathmandu   रु 13.58 Arab
# 18               Siddhartha Bank            Naxal, Kathmandu   रु 14.09 Arab
# 19       Standard Chartered Bank   Naya Baneshwor, Kathmandu   रु 10.04 Arab
#
#     Branches & Extension Counters [clarification needed] Website
# 0                                                 306        [1]
# 1                                                 296        [2]
# 2                                                 361        [3]
# 3                                                 208        [4]
# 4                                                 143        [5]
# 5                                                 443        [6]
# 6                                                 212        [7]
# 7                                                 360        [8]
# 8                                                 299        [9]
# 9                                                 185       [10]
# 10                                                296       [11]
# 11                                                355       [12]
# 12                                                130       [13]
# 13                                                486       [14]
# 14                                                219       [15]
# 15                                                395       [16]
# 16                                                201       [17]
# 17                                                141       [18]
# 18                                                205       [19]
# 19                                                 17       [20]
